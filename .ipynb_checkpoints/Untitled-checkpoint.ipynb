# %%
import pandas as pd

data = pd.read_csv('deliverable.csv')

data.head()
# Out:
#             id    site                                        description  \
# 0       budget  global  <p>National government budget at a high level,...
# 1   statistics  global  <p>Key national statistics on demographic and ...
# 2  procurement  global  <p>All tenders and awards of the national/fede...
# 3          law  global  <p>This data category requires all national la...
# 4   boundaries  global  <p>Data on administrative units or areas defin...
#
#                                      characteristics  \
# 0  Budget per government department;Budget per su...
# 1  Gross Domestic Product;National unemployment;N...
# 2  Tenders per government office;Awards per gover...
# 3  Content of the law / status;Date of last amend...
# 4  Boundary level 1;Boundary level 2;Coordinates ...
#
#                                          updateevery           category  icon  \
# 0                                               year            Finance   NaN
# ...
